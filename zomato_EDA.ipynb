# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("zomato.csv",encoding='latin-1')

# %%
df.shape
# Out:
# (9551, 21)

# %%
df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %%
df.describe()
# Out:
#        Restaurant ID  Country Code    Longitude     Latitude  \
# count   9.551000e+03   9551.000000  9551.000000  9551.000000
# mean    9.051128e+06     18.365616    64.126574    25.854381
# std     8.791521e+06     56.750546    41.467058    11.007935
# min     5.300000e+01      1.000000  -157.948486   -41.330428
# 25%     3.019625e+05      1.000000    77.081343    28.478713
# 50%     6.004089e+06      1.000000    77.191964    28.570469
# 75%     1.835229e+07      1.000000    77.282006    28.642758
# max     1.850065e+07    216.000000   174.832089    55.976980
#
#        Average Cost for two  Price range  Aggregate rating         Votes
# count           9551.000000  9551.000000       9551.000000   9551.000000
# mean            1199.210763     1.804837          2.666370    156.909748
# std            16121.183073     0.905609          1.516378    430.169145
# min                0.000000     1.000000          0.000000      0.000000
# ...

# %%
df.isnull().sum() #checking for missing values
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
df.Cuisines.head()
# Out:
# 0          French, Japanese, Desserts
# 1                            Japanese
# 2    Seafood, Asian, Filipino, Indian
# 3                     Japanese, Sushi
# 4                    Japanese, Korean
# Name: Cuisines, dtype: object

# %%
df_country=pd.read_excel('Country-Code.xlsx')

# %%
df_country.head()
# Out:
#    Country Code    Country
# 0             1      India
# 1            14  Australia
# 2            30     Brazil
# 3            37     Canada
# 4            94  Indonesia

# %%
merged_df=pd.merge(df,df_country,on="Country Code",how="left")

# %%
merged_df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
merged_df.Country.value_counts()
# Out:
# India             8652
# United States      434
# United Kingdom      80
# Brazil              60
# UAE                 60
# South Africa        60
# New Zealand         40
# Turkey              34
# Australia           24
# Phillipines         22
# Indonesia           21
# Singapore           20
# Qatar               20
# Sri Lanka           20
# Canada               4
# Name: Country, dtype: int64

# %%
country_names=merged_df.Country.value_counts().index

# %%
country_val=merged_df.Country.value_counts().values

# %%
plt.figure(figsize=(15,15))
plt.pie(country_val[:5],labels=country_names[:5],autopct='%1.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x204740d2c10>,
# ...
#  [Text(-1.07479320772197, 0.23413577393196094, 'India'),
#   Text(1.056503577535216, -0.3062681678779072, 'United States'),
#   Text(1.093560093908513, -0.118854200644337, 'United Kingdom'),
#   Text(1.0979610170116392, -0.06694479160298568, 'Brazil'),
#   Text(1.0997733864424146, -0.022327079365287286, 'UAE')],
#  [Text(-0.5862508405756199, 0.12771042214470596, '93.17%'),
#   Text(0.5762746786555722, -0.1670553642970403, '4.67%'),
#   Text(0.596487323950098, -0.06482956398782018, '0.86%'),
#   Text(0.598887827460894, -0.03651534087435582, '0.65%'),
#   Text(0.5998763926049533, -0.012178406926520337, '0.65%')])

# %%
merged_df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %%
merged_df.groupby('Country').apply(lambda x: (x['Average Cost for two']).mean())
# Out:
# Country
# Australia             24.083333
# Brazil               134.666667
# Canada                36.250000
# India                623.370319
# Indonesia         281190.476190
# New Zealand           69.750000
# Phillipines         1606.818182
# Qatar                223.750000
# Singapore            155.750000
# South Africa         419.733333
# Sri Lanka           2375.000000
# Turkey                84.852941
# UAE                  166.416667
# United Kingdom        47.812500
# United States         26.152074
# dtype: float64

# %%
merged_df[merged_df['Has Online delivery'] =="Yes"].Country.value_counts()
# Out:
# India    2423
# UAE        28
# Name: Country, dtype: int64

# %%
ratings=merged_df.groupby(['Aggregate rating','Rating color','Rating text']).size().reset_index().rename(columns={0:'Rating Count'})

# %%
ratings
# Out:
#     Aggregate rating Rating color Rating text  Rating Count
# 0                0.0        White   Not rated          2148
# 1                1.8          Red        Poor             1
# 2                1.9          Red        Poor             2
# 3                2.0          Red        Poor             7
# 4                2.1          Red        Poor            15
# 5                2.2          Red        Poor            27
# 6                2.3          Red        Poor            47
# 7                2.4          Red        Poor            87
# 8                2.5       Orange     Average           110
# 9                2.6       Orange     Average           191
# 10               2.7       Orange     Average           250
# 11               2.8       Orange     Average           315
# 12               2.9       Orange     Average           381
# 13               3.0       Orange     Average           468
# 14               3.1       Orange     Average           519
# ...

# %%
plt.rcParams['figure.figsize'] = (12, 6)
sns.barplot(x="Aggregate rating",y="Rating Count",hue='Rating color',data=ratings,palette=['blue','red','orange','yellow','green','green'])
# Out:
# <AxesSubplot:xlabel='Aggregate rating', ylabel='Rating Count'>

# %%
sns.countplot(x="Rating color",data=ratings,palette=['blue','red','orange','yellow','green','green'])
# Out:
# <AxesSubplot:xlabel='Rating color', ylabel='count'>

# %%
merged_df[merged_df['Rating color']=='White'].groupby('Country').size().reset_index().rename(columns={0:'0 Count'})
# Out:
#           Country  0 Count
# 0          Brazil        5
# 1           India     2139
# 2  United Kingdom        1
# 3   United States        3

# %%
merged_df[['Country','Currency']].groupby(['Country','Currency']).size().reset_index()
# Out:
#            Country                Currency     0
# 0        Australia               Dollar($)    24
# 1           Brazil      Brazilian Real(R$)    60
# 2           Canada               Dollar($)     4
# 3            India      Indian Rupees(Rs.)  8652
# 4        Indonesia  Indonesian Rupiah(IDR)    21
# 5      New Zealand           NewZealand($)    40
# 6      Phillipines        Botswana Pula(P)    22
# 7            Qatar         Qatari Rial(QR)    20
# 8        Singapore               Dollar($)    20
# 9     South Africa                 Rand(R)    60
# 10       Sri Lanka   Sri Lankan Rupee(LKR)    20
# 11          Turkey        Turkish Lira(TL)    34
# 12             UAE      Emirati Diram(AED)    60
# 13  United Kingdom              Pounds(£)    80
# 14   United States               Dollar($)   434

# %%
merged_df[merged_df['Has Online delivery'] =="Yes"].Country.value_counts()
# Out:
# India    2423
# UAE        28
# Name: Country, dtype: int64

# %%
merged_df[['Has Online delivery','Country']].groupby(['Has Online delivery','Country']).size().reset_index()
# Out:
#    Has Online delivery         Country     0
# 0                   No       Australia    24
# 1                   No          Brazil    60
# 2                   No          Canada     4
# 3                   No           India  6229
# 4                   No       Indonesia    21
# 5                   No     New Zealand    40
# 6                   No     Phillipines    22
# 7                   No           Qatar    20
# 8                   No       Singapore    20
# 9                   No    South Africa    60
# 10                  No       Sri Lanka    20
# 11                  No          Turkey    34
# 12                  No             UAE    32
# 13                  No  United Kingdom    80
# 14                  No   United States   434
# 15                 Yes           India  2423
# 16                 Yes             UAE    28

# %%
merged_df.City.value_counts()
# Out:
# New Delhi           5473
# Gurgaon             1118
# Noida               1080
# Faridabad            251
# Ghaziabad             25
#                     ...
# Panchkula              1
# Mc Millan              1
# Mayfield               1
# Macedon                1
# Vineland Station       1
# Name: City, Length: 141, dtype: int64

# %%
city_values=merged_df.City.value_counts().values
city_labels=merged_df.City.value_counts().index

# %%
plt.pie(city_values[:5],labels=city_labels[:5],autopct='%1.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x2047228b3a0>,
# ...
#  [Text(-0.6145352824185932, 0.9123301960708633, 'New Delhi'),
#   Text(0.0623675251198054, -1.0982305276263407, 'Gurgaon'),
#   Text(0.8789045225625368, -0.6614581167535246, 'Noida'),
#   Text(1.0922218418223437, -0.13058119407559224, 'Faridabad'),
#   Text(1.099946280005612, -0.010871113182029924, 'Ghaziabad')],
#  [Text(-0.3352010631374145, 0.497634652402289, '68.87%'),
#   Text(0.0340186500653484, -0.5990348332507311, '14.07%'),
#   Text(0.47940246685229276, -0.36079533641101336, '13.59%'),
#   Text(0.5957573682667329, -0.07122610585941394, '3.16%'),
#   Text(0.5999706981848791, -0.005929698099289049, '0.31%')])

# %%
merged_df.Cuisines.value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0             French, Japanese, Desserts
# 1                               Japanese
# 2       Seafood, Asian, Filipino, Indian
# 3                        Japanese, Sushi
# 4                       Japanese, Korean
#                       ...
# 9546                             Turkish
# 9547     World Cuisine, Patisserie, Cafe
# 9548              Italian, World Cuisine
# 9549                     Restaurant Cafe
# 9550                                Cafe
# Name: Cuisines, Length: 9551, dtype: object>

# %%
cuisines_split =merged_df['Cuisines'].str.split(', ',expand=True)

# %%
cuisines_split.head()
# Out:
#           0         1         2       3     4     5     6     7
# 0    French  Japanese  Desserts    None  None  None  None  None
# 1  Japanese      None      None    None  None  None  None  None
# 2   Seafood     Asian  Filipino  Indian  None  None  None  None
# 3  Japanese     Sushi      None    None  None  None  None  None
# 4  Japanese    Korean      None    None  None  None  None  None

# %%
cuisines0=pd.DataFrame(cuisines_split[0].value_counts()).reset_index().rename(columns={0:'0'})
cuisines1=pd.DataFrame(cuisines_split[1].value_counts()).reset_index().rename(columns={0:'1'})
cuisines2=pd.DataFrame(cuisines_split[2].value_counts()).reset_index().rename(columns={0:'2'})
cuisines3=pd.DataFrame(cuisines_split[3].value_counts()).reset_index().rename(columns={0:'3'})
cuisines4=pd.DataFrame(cuisines_split[4].value_counts()).reset_index().rename(columns={0:'4'})
cuisines5=pd.DataFrame(cuisines_split[5].value_counts()).reset_index().rename(columns={0:'5'})
cuisines6=pd.DataFrame(cuisines_split[6].value_counts()).reset_index().rename(columns={0:'6'})
cuisines7=pd.DataFrame(cuisines_split[7].value_counts()).reset_index().rename(columns={0:'7'})

# %%
cuisines0.head(5)
# Out:
#           index     0
# 0  North Indian  2992
# 1       Chinese   855
# 2     Fast Food   672
# 3        Bakery   621
# 4          Cafe   617

# %%
cuisines1.head(5)
# Out:
#           index     1
# 0       Chinese  1156
# 1     Fast Food   820
# 2  North Indian   687
# 3       Mughlai   635
# 4      Desserts   407

# %%
cuisines2.head(5)
# Out:
#           index    2
# 0       Chinese  594
# 1     Fast Food  385
# 2   Continental  193
# 3  North Indian  191
# 4       Italian  189

# %%
cuisines3.head(5)
# Out:
#           index   3
# 0       Italian  85
# 1       Chinese  81
# 2     Fast Food  77
# 3  Healthy Food  67
# 4  North Indian  65

# %%
cuisines4.head(5)
# Out:
#           index   4
# 0       Chinese  41
# 1     Fast Food  30
# 2  North Indian  23
# 3          Thai  20
# 4       Italian  13

# %%
cuisines5.head(5)
# Out:
#        index   5
# 0     Mithai  23
# 1  Beverages  12
# 2    Chinese   8
# 3   Lebanese   8
# 4       Thai   5

# %%
cuisines6.head(5)
# Out:
#            index   6
# 0       Desserts  24
# 1  Mediterranean   2
# 2       European   2
# 3         Mithai   2
# 4       Lebanese   1

# %%
cuisines7.head(5)
# Out:
#            index  7
# 0         Mithai  8
# 1    Finger Food  2
# 2  International  2
# 3      Beverages  1
# 4        Mughlai  1

# %%
merged_cuisines1=pd.merge(cuisines0,cuisines1,how='outer',on='index')
merged_cuisines1
# Out:
#             index       0       1
# 0    North Indian  2992.0   687.0
# 1         Chinese   855.0  1156.0
# 2       Fast Food   672.0   820.0
# 3          Bakery   621.0    67.0
# 4            Cafe   617.0    40.0
# ..            ...     ...     ...
# 132          Deli     NaN     1.0
# 133       Belgian     NaN     1.0
# 134      Teriyaki     NaN     1.0
# 135      Canadian     NaN     1.0
# 136       Mineira     NaN     1.0
#
# [137 rows x 3 columns]

# %%
merged_cuisines2=pd.merge(merged_cuisines1,cuisines2,how='outer',on='index')
merged_cuisines2
# Out:
#             index       0       1      2
# 0    North Indian  2992.0   687.0  191.0
# 1         Chinese   855.0  1156.0  594.0
# 2       Fast Food   672.0   820.0  385.0
# 3          Bakery   621.0    67.0   27.0
# 4            Cafe   617.0    40.0   25.0
# ..            ...     ...     ...    ...
# 138      Armenian     NaN     NaN    2.0
# 139     Cantonese     NaN     NaN    2.0
# 140        Dí_ner     NaN     NaN    1.0
# 141        Durban     NaN     NaN    1.0
# 142     Soul Food     NaN     NaN    1.0
#
# [143 rows x 4 columns]

# %%
merged_cuisines3=pd.merge(merged_cuisines2,cuisines3,how='outer',on='index')
merged_cuisines3
# Out:
#             index       0       1      2     3
# 0    North Indian  2992.0   687.0  191.0  65.0
# 1         Chinese   855.0  1156.0  594.0  81.0
# 2       Fast Food   672.0   820.0  385.0  77.0
# 3          Bakery   621.0    67.0   27.0  19.0
# 4            Cafe   617.0    40.0   25.0  14.0
# ..            ...     ...     ...    ...   ...
# 140        Dí_ner     NaN     NaN    1.0   NaN
# 141        Durban     NaN     NaN    1.0   NaN
# 142     Soul Food     NaN     NaN    1.0   NaN
# 143         Malay     NaN     NaN    NaN   1.0
# 144    Bubble Tea     NaN     NaN    NaN   1.0
#
# [145 rows x 5 columns]

# %%
merged_cuisines4=pd.merge(merged_cuisines3,cuisines4,how='outer',on='index')
merged_cuisines4
# Out:
#             index       0       1      2     3     4
# 0    North Indian  2992.0   687.0  191.0  65.0  23.0
# 1         Chinese   855.0  1156.0  594.0  81.0  41.0
# 2       Fast Food   672.0   820.0  385.0  77.0  30.0
# 3          Bakery   621.0    67.0   27.0  19.0   8.0
# 4            Cafe   617.0    40.0   25.0  14.0   3.0
# ..            ...     ...     ...    ...   ...   ...
# 140        Dí_ner     NaN     NaN    1.0   NaN   NaN
# 141        Durban     NaN     NaN    1.0   NaN   NaN
# 142     Soul Food     NaN     NaN    1.0   NaN   NaN
# 143         Malay     NaN     NaN    NaN   1.0   NaN
# 144    Bubble Tea     NaN     NaN    NaN   1.0   NaN
#
# [145 rows x 6 columns]

# %%
merged_cuisines5=pd.merge(merged_cuisines4,cuisines5,how='outer',on='index')
merged_cuisines5
# Out:
#             index       0       1      2     3     4    5
# 0    North Indian  2992.0   687.0  191.0  65.0  23.0  1.0
# 1         Chinese   855.0  1156.0  594.0  81.0  41.0  8.0
# 2       Fast Food   672.0   820.0  385.0  77.0  30.0  2.0
# 3          Bakery   621.0    67.0   27.0  19.0   8.0  2.0
# 4            Cafe   617.0    40.0   25.0  14.0   3.0  4.0
# ..            ...     ...     ...    ...   ...   ...  ...
# 140        Dí_ner     NaN     NaN    1.0   NaN   NaN  NaN
# 141        Durban     NaN     NaN    1.0   NaN   NaN  NaN
# 142     Soul Food     NaN     NaN    1.0   NaN   NaN  NaN
# 143         Malay     NaN     NaN    NaN   1.0   NaN  NaN
# 144    Bubble Tea     NaN     NaN    NaN   1.0   NaN  NaN
#
# [145 rows x 7 columns]

# %%
merged_cuisines6=pd.merge(merged_cuisines5,cuisines6,how='outer',on='index')
merged_cuisines6
# Out:
#             index       0       1      2     3     4    5    6
# 0    North Indian  2992.0   687.0  191.0  65.0  23.0  1.0  1.0
# 1         Chinese   855.0  1156.0  594.0  81.0  41.0  8.0  NaN
# 2       Fast Food   672.0   820.0  385.0  77.0  30.0  2.0  NaN
# 3          Bakery   621.0    67.0   27.0  19.0   8.0  2.0  1.0
# 4            Cafe   617.0    40.0   25.0  14.0   3.0  4.0  NaN
# ..            ...     ...     ...    ...   ...   ...  ...  ...
# 140        Dí_ner     NaN     NaN    1.0   NaN   NaN  NaN  NaN
# 141        Durban     NaN     NaN    1.0   NaN   NaN  NaN  NaN
# 142     Soul Food     NaN     NaN    1.0   NaN   NaN  NaN  NaN
# 143         Malay     NaN     NaN    NaN   1.0   NaN  NaN  NaN
# 144    Bubble Tea     NaN     NaN    NaN   1.0   NaN  NaN  NaN
#
# [145 rows x 8 columns]

# %%
merged_cuisines7=pd.merge(merged_cuisines6,cuisines7,how='outer',on='index')
merged_cuisines7
# Out:
#             index       0       1      2     3     4    5    6   7
# 0    North Indian  2992.0   687.0  191.0  65.0  23.0  1.0  1.0 NaN
# 1         Chinese   855.0  1156.0  594.0  81.0  41.0  8.0  NaN NaN
# 2       Fast Food   672.0   820.0  385.0  77.0  30.0  2.0  NaN NaN
# 3          Bakery   621.0    67.0   27.0  19.0   8.0  2.0  1.0 NaN
# 4            Cafe   617.0    40.0   25.0  14.0   3.0  4.0  NaN NaN
# ..            ...     ...     ...    ...   ...   ...  ...  ...  ..
# 140        Dí_ner     NaN     NaN    1.0   NaN   NaN  NaN  NaN NaN
# 141        Durban     NaN     NaN    1.0   NaN   NaN  NaN  NaN NaN
# 142     Soul Food     NaN     NaN    1.0   NaN   NaN  NaN  NaN NaN
# 143         Malay     NaN     NaN    NaN   1.0   NaN  NaN  NaN NaN
# 144    Bubble Tea     NaN     NaN    NaN   1.0   NaN  NaN  NaN NaN
#
# [145 rows x 9 columns]

# %%
merged_cuisines7['Total_count']=merged_cuisines7.sum(axis=1)
# Out:
# C:\Users\nidhi\AppData\Local\Temp\ipykernel_14380\240932825.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   merged_cuisines7['Total_count']=merged_cuisines7.sum(axis=1)

# %%
merged_cuisines7
# Out:
#             index       0       1      2     3     4    5    6   7  \
# 0    North Indian  2992.0   687.0  191.0  65.0  23.0  1.0  1.0 NaN
# 1         Chinese   855.0  1156.0  594.0  81.0  41.0  8.0  NaN NaN
# 2       Fast Food   672.0   820.0  385.0  77.0  30.0  2.0  NaN NaN
# 3          Bakery   621.0    67.0   27.0  19.0   8.0  2.0  1.0 NaN
# 4            Cafe   617.0    40.0   25.0  14.0   3.0  4.0  NaN NaN
# ..            ...     ...     ...    ...   ...   ...  ...  ...  ..
# 140        Dí_ner     NaN     NaN    1.0   NaN   NaN  NaN  NaN NaN
# 141        Durban     NaN     NaN    1.0   NaN   NaN  NaN  NaN NaN
# 142     Soul Food     NaN     NaN    1.0   NaN   NaN  NaN  NaN NaN
# 143         Malay     NaN     NaN    NaN   1.0   NaN  NaN  NaN NaN
# 144    Bubble Tea     NaN     NaN    NaN   1.0   NaN  NaN  NaN NaN
#
#      Total_count
# 0         3960.0
# 1         2735.0
# 2         1986.0
# 3          745.0
# 4          703.0
# ..           ...
# 140          1.0
# ...

# %%
plt.bar(merged_cuisines7['index'].head(5),merged_cuisines7['Total_count'].head(5))
# Out:
# <BarContainer object of 5 artists>

# %%
merged_df['Price range'].describe()
# Out:
# count    9551.000000
# mean        1.804837
# std         0.905609
# min         1.000000
# 25%         1.000000
# 50%         2.000000
# 75%         2.000000
# max         4.000000
# Name: Price range, dtype: float64

# %%
merged_df['Price range'].value_counts()
# Out:
# 1    4444
# 2    3113
# 3    1408
# 4     586
# Name: Price range, dtype: int64
